# %%
# Dependencies
import pandas as pd 
import numpy as py 
import matplotlib.pyplot as plt

# %%
file = 'tournamentdata/new/playerstats_cleaned1.csv'
df = pd.read_csv(file, encoding="ISO-8859-1")

# %%
df.head(10)
# Out:
#      Player  Age             Team  Maps  Kills  Deaths  Assists  KillperDeath  \
# 0    zekken   19        Sentinels    20    381     314       90          1.21
# 1    ZmjjKK   20    EDward Gaming     8    135     125       39          1.08
# 2   N4RRATE   21     Karmine Corp     7    132     104       65          1.26
# 3   MiniBoo   19    Team Heretics     6    114      92       37          1.23
# 4    Autumn   23  FunPlus Phoenix     4     68      71       16          0.95
# 5      Life   22  FunPlus Phoenix     4     71      68       10          1.04
# 6     RieNs   19    Team Heretics     6    103      90       44          1.14
# 7    Meteor   24    Gen.G Esports    16    268     236       61          1.13
# 8   t3xture   24    Gen.G Esports    16    264     246       53          1.07
# 9  cauanzin   19             LOUD    12    195     178       72          1.09
#
#     KDA  ACS/Map  K/Map  D/Map  A/Map
# 0  1.50      259   19.0   15.7    4.5
# 1  1.39      252   16.8   15.6    4.8
# 2  1.89      245   18.8   14.8    9.2
# 3  1.64      245   19.0   15.3    6.1
# 4  1.18      231   17.0   17.7    4.0
# 5  1.19      230   17.7   17.0    2.5
# 6  1.63      230   17.1   15.0    7.3
# 7  1.39      230   16.7   14.7    3.8
# 8  1.28      224   16.5   15.3    3.3
# 9  1.50      223   16.2   14.8    6.0
