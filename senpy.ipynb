# %%
# Dependencies
import pandas as pd 
import numpy as py 
import matplotlib.pyplot as plt

# %%
file = 'tournamentdata/new/playerstats_cleaned1.csv'
df = pd.read_csv(file, encoding="ISO-8859-1")

# %%
df
# Out:
#         Player  Age             Team  Maps  Kills  Deaths  Assists  \
# 0       zekken   19        Sentinels    20    381     314       90
# 1       ZmjjKK   20    EDward Gaming     8    135     125       39
# 2      N4RRATE   21     Karmine Corp     7    132     104       65
# 3      MiniBoo   19    Team Heretics     6    114      92       37
# 4       Autumn   23  FunPlus Phoenix     4     68      71       16
# 5         Life   22  FunPlus Phoenix     4     71      68       10
# 6        RieNs   19    Team Heretics     6    103      90       44
# 7       Meteor   24    Gen.G Esports    16    268     236       61
# 8      t3xture   24    Gen.G Esports    16    264     246       53
# 9     cauanzin   19             LOUD    12    195     178       72
# 10         qck   20             LOUD    12    193     187       39
# 11  benjyfishy   20    Team Heretics     6    101      90       30
# 12    f0rsakeN   20        Paper Rex    17    273     268      132
# ...

# %%
grouped_df = df.sort_values(
    by="Kills",
    ascending=False)
grouped_df
# Out:
#         Player  Age             Team  Maps  Kills  Deaths  Assists  \
# 0       zekken   19        Sentinels    20    381     314       90
# 16        TenZ   23        Sentinels    20    314     300      226
# 19      johnqt   26        Sentinels    20    293     251      117
# 15   something   22        Paper Rex    17    274     254       79
# 12    f0rsakeN   20        Paper Rex    17    273     268      132
# 7       Meteor   24    Gen.G Esports    16    268     236       61
# 8      t3xture   24    Gen.G Esports    16    264     246       53
# 25     Zellsis   26        Sentinels    20    263     282      172
# 18      Monyet   19        Paper Rex    17    250     289      110
# 28        Sacy   26        Sentinels    20    249     289      169
# 17       Karon   22    Gen.G Esports    16    242     229      119
# 26       d4v41   25        Paper Rex    17    234     259      143
# 24    Munchkin   26    Gen.G Esports    16    220     201      131
# ...

# %%
grouped_df.head(10)
print(grouped_df.loc[grouped_df['Team'] == 'Sentinels'])
# Out:
#      Player  Age       Team  Maps  Kills  Deaths  Assists  KillperDeath   KDA  \
# 0    zekken   19  Sentinels    20    381     314       90          1.21  1.50
# 16     TenZ   23  Sentinels    20    314     300      226          1.04  1.80
# 19   johnqt   26  Sentinels    20    293     251      117          1.16  1.63
# 25  Zellsis   26  Sentinels    20    263     282      172          0.93  1.54
# 28     Sacy   26  Sentinels    20    249     289      169          0.86  1.44
#
#     ACS/Map  K/Map  D/Map  A/Map
# 0       259   19.0   15.7    4.5
# 16      208   15.7   15.0   11.3
# 19      198   14.6   12.5    5.8
# 25      188   13.1   14.1    8.6
# 28      173   12.4   14.4    8.4
