# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data_df = pd.read_csv("tournamentdata/new/playerstats_cleaned1.csv")
data_df.head()
# Out:
#     Player  Age             Team  Maps  Kills  Deaths  Assists  KillperDeath  \
# 0   zekken   19        Sentinels    20    381     314       90          1.21
# 1   ZmjjKK   20    EDward Gaming     8    135     125       39          1.08
# 2  N4RRATE   21     Karmine Corp     7    132     104       65          1.26
# 3  MiniBoo   19    Team Heretics     6    114      92       37          1.23
# 4   Autumn   23  FunPlus Phoenix     4     68      71       16          0.95
#
#     KDA  ACS/Map  K/Map  D/Map  A/Map
# 0  1.50      259   19.0   15.7    4.5
# 1  1.39      252   16.8   15.6    4.8
# 2  1.89      245   18.8   14.8    9.2
# 3  1.64      245   19.0   15.3    6.1
# 4  1.18      231   17.0   17.7    4.0

# %%
x_axis = np.arange(len(data_df))
tick_locations = [value for value in x_axis]

# %%
plt.figure(figsize=(16,4))
plt.bar(x_axis, data_df["Kills"], color='r', alpha=0.5)
plt.xticks(tick_locations, data_df["Player"], rotation="vertical")
plt.title("Total Amount of Kills (Unordered)")
plt.xlabel("Name of Player")
plt.ylabel("Number of Kills")
# Out:
# Text(0, 0.5, 'Number of Kills')

# %%
grouped_df = data_df.sort_values(
    by="Kills",
    ascending=False)
grouped_df
# Out:
#         Player  Age             Team  Maps  Kills  Deaths  Assists  \
# 0       zekken   19        Sentinels    20    381     314       90
# 16        TenZ   23        Sentinels    20    314     300      226
# 19      johnqt   26        Sentinels    20    293     251      117
# 15   something   22        Paper Rex    17    274     254       79
# 12    f0rsakeN   20        Paper Rex    17    273     268      132
# 7       Meteor   24    Gen.G Esports    16    268     236       61
# 8      t3xture   24    Gen.G Esports    16    264     246       53
# 25     Zellsis   26        Sentinels    20    263     282      172
# 18      Monyet   19        Paper Rex    17    250     289      110
# 28        Sacy   26        Sentinels    20    249     289      169
# 17       Karon   22    Gen.G Esports    16    242     229      119
# 26       d4v41   25        Paper Rex    17    234     259      143
# 24    Munchkin   26    Gen.G Esports    16    220     201      131
# ...

# %%
plt.figure(figsize=(12,4))
plt.bar(x_axis, grouped_df["Kills"], color='r', alpha=0.5)
plt.xticks(tick_locations, grouped_df["Player"], rotation="vertical")
plt.title("Total Amount of Kills (Ordered)")
plt.xlabel("Name of Player")
plt.ylabel("Number of Kills")
# Out:
# Text(0, 0.5, 'Number of Kills')

# %%
teams_df = grouped_df.sort_values(
    by="Kills",
    ascending=False)
teams_df
# Out:
#         Player  Age             Team  Maps  Kills  Deaths  Assists  \
# 0       zekken   19        Sentinels    20    381     314       90
# 16        TenZ   23        Sentinels    20    314     300      226
# 19      johnqt   26        Sentinels    20    293     251      117
# 15   something   22        Paper Rex    17    274     254       79
# 12    f0rsakeN   20        Paper Rex    17    273     268      132
# 7       Meteor   24    Gen.G Esports    16    268     236       61
# 8      t3xture   24    Gen.G Esports    16    264     246       53
# 25     Zellsis   26        Sentinels    20    263     282      172
# 18      Monyet   19        Paper Rex    17    250     289      110
# 28        Sacy   26        Sentinels    20    249     289      169
# 17       Karon   22    Gen.G Esports    16    242     229      119
# 26       d4v41   25        Paper Rex    17    234     259      143
# 24    Munchkin   26    Gen.G Esports    16    220     201      131
# ...

# %%
reducedteams_df = teams_df[["Player", "Team", "Kills", "Deaths"]]
reducedteams_df.head()
# Out:
#        Player       Team  Kills  Deaths
# 0      zekken  Sentinels    381     314
# 16       TenZ  Sentinels    314     300
# 19     johnqt  Sentinels    293     251
# 15  something  Paper Rex    274     254
# 12   f0rsakeN  Paper Rex    273     268

# %%
reducedteams_df["Team Player"] = reducedteams_df["Team"] + ' ' + reducedteams_df['Player']
print(reducedteams_df)
# Out:
#         Player             Team  Kills  Deaths               Team Player
# 0       zekken        Sentinels    381     314          Sentinels zekken
# 16        TenZ        Sentinels    314     300            Sentinels TenZ
# 19      johnqt        Sentinels    293     251          Sentinels johnqt
# 15   something        Paper Rex    274     254       Paper Rex something
# 12    f0rsakeN        Paper Rex    273     268        Paper Rex f0rsakeN
# 7       Meteor    Gen.G Esports    268     236      Gen.G Esports Meteor
# 8      t3xture    Gen.G Esports    264     246     Gen.G Esports t3xture
# 25     Zellsis        Sentinels    263     282         Sentinels Zellsis
# 18      Monyet        Paper Rex    250     289          Paper Rex Monyet
# 28        Sacy        Sentinels    249     289            Sentinels Sacy
# 17       Karon    Gen.G Esports    242     229       Gen.G Esports Karon
# 26       d4v41        Paper Rex    234     259           Paper Rex d4v41
# ...

# %%
reducedteams_df.head()
# Out:
#        Player       Team  Kills  Deaths          Team Player
# 0      zekken  Sentinels    381     314     Sentinels zekken
# 16       TenZ  Sentinels    314     300       Sentinels TenZ
# 19     johnqt  Sentinels    293     251     Sentinels johnqt
# 15  something  Paper Rex    274     254  Paper Rex something
# 12   f0rsakeN  Paper Rex    273     268   Paper Rex f0rsakeN

# %%
# Removed "Player" and "Team" as they were combined. 
reducedteams_df = reducedteams_df.drop(["Player", "Team"], axis = 1)
print(reducedteams_df)
# Out:
#     Kills  Deaths               Team Player
# 0     381     314          Sentinels zekken
# 16    314     300            Sentinels TenZ
# 19    293     251          Sentinels johnqt
# 15    274     254       Paper Rex something
# 12    273     268        Paper Rex f0rsakeN
# 7     268     236      Gen.G Esports Meteor
# 8     264     246     Gen.G Esports t3xture
# 25    263     282         Sentinels Zellsis
# 18    250     289          Paper Rex Monyet
# 28    249     289            Sentinels Sacy
# 17    242     229       Gen.G Esports Karon
# 26    234     259           Paper Rex d4v41
# 24    220     201    Gen.G Esports Munchkin
# 31    217     258       Paper Rex mindfreak
# 14    195     148                 LOUD Less
# 9     195     178             LOUD cauanzin
# 10    193     187                  LOUD qck
# 23    186     144                 LOUD tuyz
# 34    177     228       Gen.G Esports Lakia
# 22    162     163              LOUD Saadhak
# ...

# %%
sen_team_stat = reducedteams_df[reducedteams_df["Team Player"].str.contains("Sentinels")][['Kills', "Deaths"]].sum()
print(sen_team_stat)
# Out:
# Kills     1500
# Deaths    1436
# dtype: int64

# %%
multi_plot = reducedteams_df.plot(kind="bar", figsize=(20,5))

multi_plot.set_xticklabels(reducedteams_df["Team Player"], rotation=90)

bar_width = 0.35
plt.bar(reducedteams_df['Kills'], bar_width, label='Kills', color='r')
plt.bar(reducedteams_df['Deaths'], bar_width, label='Deaths', color='b')

plt.title("Kill / Death Ratio of Each Player")
plt.xlabel("Team and Name of Player")
plt.ylabel("Number of Kills and Deaths")
plt.show()

# %%
reducedteams_df.head()
# Out:
#     Kills  Deaths          Team Player
# 0     381     314     Sentinels zekken
# 16    314     300       Sentinels TenZ
# 19    293     251     Sentinels johnqt
# 15    274     254  Paper Rex something
# 12    273     268   Paper Rex f0rsakeN

# %%
#Removed every team that did not advance to the playoffs.

playoff_teams_df = reducedteams_df[~reducedteams_df["Team Player"].str.contains("EDward Gaming|Team Heretics|Karmine Corp|FunPlus Phoenix")]
#playoff_teams_df = reducedteams_df[~reducedteams_df["Team Player"].str.contains("Team Heretics")]
#playoff_teams_df = reducedteams_df[~reducedteams_df["Team Player"].str.contains("Karmine Corp")]
# playoff_teams_df = reducedteams_df[~reducedteams_df["Team Player"].str.contains("FunPlus Phoenix")]

#playoff_teams_df = reducedteams_df[reducedteams_df['Team Player'] != 'EDWard Gaming']

print(playoff_teams_df)
playoff_teams_df.head()
# Out:
#     Kills  Deaths             Team Player
# 0     381     314        Sentinels zekken
# 16    314     300          Sentinels TenZ
# 19    293     251        Sentinels johnqt
# 15    274     254     Paper Rex something
# 12    273     268      Paper Rex f0rsakeN
# 7     268     236    Gen.G Esports Meteor
# 8     264     246   Gen.G Esports t3xture
# 25    263     282       Sentinels Zellsis
# 18    250     289        Paper Rex Monyet
# 28    249     289          Sentinels Sacy
# 17    242     229     Gen.G Esports Karon
# 26    234     259         Paper Rex d4v41
# 24    220     201  Gen.G Esports Munchkin
# 31    217     258     Paper Rex mindfreak
# 14    195     148               LOUD Less
# 9     195     178           LOUD cauanzin
# 10    193     187                LOUD qck
# 23    186     144               LOUD tuyz
# 34    177     228     Gen.G Esports Lakia
# 22    162     163            LOUD Saadhak
#     Kills  Deaths          Team Player
# ...

# %%
multi_plot = playoff_teams_df.plot(kind="bar", figsize=(20,5))

multi_plot.set_xticklabels(playoff_teams_df["Team Player"])

plt.xticks(rotation = 90, fontsize=10)
plt.title("Kill / Death Ratio of Each Player from Playoffs")
plt.xlabel("Team and Name of Player")
plt.ylabel("Number of Kills and Deaths")
plt.show()

# %%
reducedteams_df.dtypes
# Out:
# Kills           int64
# Deaths          int64
# Team Player    object
# dtype: object
